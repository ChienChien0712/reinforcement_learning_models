# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20,10)
plt.rcParams['figure.dpi'] = 100

# %%
game = 'MsPacman-v4'

# %%
f1 = open('logs/{0}_log'.format(game))
txt = f1.readlines()
f1.close()

MA100 = [float(i.strip().split(',')[-1][7:]) for i in txt if 'MA100' in i]
total_reward = [float(i.strip().split(',')[-3][16:]) for i in txt if 'episode reward' in i]

plt.plot(total_reward, label='Total Reward')
plt.plot(MA100, label='MA100')
plt.xlabel('Episode of Test', fontsize=20)
plt.ylabel('Total Reward', fontsize=20)
plt.title(f'{game}', fontsize=32)
plt.legend(fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()
